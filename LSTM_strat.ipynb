# %%
# Install required libraries
# !pip install ta tensorflow
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ta) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=1ea9f91c1486b2645f6dc0cb46794095ec67cb8d417d30628660796010c894a6
#   Stored in directory: /root/.cache/pip/wheels/5c/a1/5f/c6b85a7d9452057be4ce68a8e45d77ba34234a6d46581777c6
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
# Determinism & seeds
import os, random, numpy as np
SEED = 42

# Python & NumPy
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# TensorFlow determinism flags
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"


import tensorflow as tf
tf.keras.utils.set_random_seed(SEED)            # sets python, numpy, and tf seeds

# Reduce nondeterminism from thread scheduling
tf.config.threading.set_intra_op_parallelism_threads(1)
tf.config.threading.set_inter_op_parallelism_threads(1)

# For newer TF versions (silently ignore if not available)
try:
    tf.config.experimental.enable_op_determinism(True)
except Exception:
    pass

# %% [markdown]
# ### Imports

# %%
# Remove unwanted warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# Data Management
import pandas as pd
import numpy as np
from pandas_datareader.data import DataReader
import yfinance as yf

# Technical Analysis
from ta import add_all_ta_features

# Statistics
from statsmodels.tsa.stattools import adfuller

# Machine Learning and Deep Learning
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Reporting
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Extraction

# %%
# Data Extraction
start_date = "2017-12-01"
end_date = "2025-10-01"
symbol = "BTC-USD"  # change it as needed "ETH-USD", "XRP-USD"
df = yf.download(symbol, start=start_date, end=end_date)
df.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
print(df.shape)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# (2861, 5)
#                    Close          High           Low          Open      Volume
# Date
# 2017-12-01  10975.599609  11046.700195   9694.650391  10198.599609  6783119872
# 2017-12-02  11074.599609  11320.200195  10905.099609  10978.299805  5138500096
# 2017-12-03  11323.200195  11858.700195  10862.000000  11082.700195  6608309760
# 2017-12-04  11657.200195  11657.200195  11081.799805  11315.400391  6132409856
# 2017-12-05  11916.700195  12032.000000  11604.599609  11685.700195  6895260160

# %%
# Add TA
df = add_all_ta_features(df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
df.head()
# Out:
#                    Close          High           Low          Open  \
# Date
# 2017-12-01  10975.599609  11046.700195   9694.650391  10198.599609
# 2017-12-02  11074.599609  11320.200195  10905.099609  10978.299805
# 2017-12-03  11323.200195  11858.700195  10862.000000  11082.700195
# 2017-12-04  11657.200195  11657.200195  11081.799805  11315.400391
# 2017-12-05  11916.700195  12032.000000  11604.599609  11685.700195
#
#                 Volume    volume_adi   volume_obv  volume_cmf     volume_fi  \
# Date
# 2017-12-01  6783119872  6.069709e+09   6783119872    0.894825  0.000000e+00
# 2017-12-02  5138500096  5.127665e+09  11921619968    0.430115  5.087115e+11
# 2017-12-03  6608309760  4.635043e+09  18529929728    0.250138  6.707284e+11
# 2017-12-04  6132409856  1.076745e+10  24662339584    0.436595  8.675136e+11
# 2017-12-05  6895260160  1.394244e+10  31557599744    0.441809  9.992002e+11
#
#               volume_em  ...  momentum_ppo  momentum_ppo_signal  \
# Date                     ...
# 2017-12-01     0.000000  ...      0.000000             0.000000
# 2017-12-02  5993.852084  ...      0.071906             0.014381
# 2017-12-03  3735.945227  ...      0.307284             0.072962
# 2017-12-04    85.852993  ...      0.727186             0.203807
# 2017-12-05  2781.870551  ...      1.229076             0.408861
#
#             momentum_ppo_hist  momentum_pvo  momentum_pvo_signal  \
# Date
# 2017-12-01           0.000000      0.000000             0.000000
# 2017-12-02           0.057525     -1.969508            -0.393902
# 2017-12-03           0.234322     -1.730980            -0.661317
# 2017-12-04           0.523379     -2.106013            -0.950256
# 2017-12-05           0.820215     -1.443943            -1.048994
#
#             momentum_pvo_hist  momentum_kama  others_dr  others_dlr  others_cr
# Date
# 2017-12-01           0.000000   10975.599609   0.000000    0.000000   0.000000
# 2017-12-02          -1.575606   11018.447437   0.902001    0.897957   0.902001
# 2017-12-03          -1.069663   11147.496158   2.244782    2.219957   3.167030
# 2017-12-04          -1.155756   11365.861032   2.949696    2.907030   6.210144
# 2017-12-05          -0.394950   11582.265655   2.226092    2.201676   8.574480
#
# [5 rows x 91 columns]

# %%
# ---- TARGET setting ----
df["TARGET"] = 0
df.loc[df["Close"].shift(-1) > df["Close"], "TARGET"] = 1
# Drop last row where next-day Close is undefined
df = df.iloc[:-1].copy()
df.head()
# Out:
#                    Close          High           Low          Open  \
# Date
# 2017-12-01  10975.599609  11046.700195   9694.650391  10198.599609
# 2017-12-02  11074.599609  11320.200195  10905.099609  10978.299805
# 2017-12-03  11323.200195  11858.700195  10862.000000  11082.700195
# 2017-12-04  11657.200195  11657.200195  11081.799805  11315.400391
# 2017-12-05  11916.700195  12032.000000  11604.599609  11685.700195
#
#                 Volume    volume_adi   volume_obv  volume_cmf     volume_fi  \
# Date
# 2017-12-01  6783119872  6.069709e+09   6783119872    0.894825  0.000000e+00
# 2017-12-02  5138500096  5.127665e+09  11921619968    0.430115  5.087115e+11
# 2017-12-03  6608309760  4.635043e+09  18529929728    0.250138  6.707284e+11
# 2017-12-04  6132409856  1.076745e+10  24662339584    0.436595  8.675136e+11
# 2017-12-05  6895260160  1.394244e+10  31557599744    0.441809  9.992002e+11
#
#               volume_em  ...  momentum_ppo_signal  momentum_ppo_hist  \
# Date                     ...
# 2017-12-01     0.000000  ...             0.000000           0.000000
# 2017-12-02  5993.852084  ...             0.014381           0.057525
# 2017-12-03  3735.945227  ...             0.072962           0.234322
# 2017-12-04    85.852993  ...             0.203807           0.523379
# 2017-12-05  2781.870551  ...             0.408861           0.820215
#
#             momentum_pvo  momentum_pvo_signal  momentum_pvo_hist  \
# Date
# 2017-12-01      0.000000             0.000000           0.000000
# 2017-12-02     -1.969508            -0.393902          -1.575606
# 2017-12-03     -1.730980            -0.661317          -1.069663
# 2017-12-04     -2.106013            -0.950256          -1.155756
# 2017-12-05     -1.443943            -1.048994          -0.394950
#
#             momentum_kama  others_dr  others_dlr  others_cr  TARGET
# Date
# 2017-12-01   10975.599609   0.000000    0.000000   0.000000       1
# 2017-12-02   11018.447437   0.902001    0.897957   0.902001       1
# 2017-12-03   11147.496158   2.244782    2.219957   3.167030       1
# 2017-12-04   11365.861032   2.949696    2.907030   6.210144       1
# 2017-12-05   11582.265655   2.226092    2.201676   8.574480       1
#
# [5 rows x 92 columns]

# %% [markdown]
# ### Data Preprocessing - Stationarity

# %%
# Identify non-stationary columns among FEATURES ONLY
non_stationaries = []
for col in df.columns:
    if col == "TARGET":
        continue  # don't test/transform the label
    try:
        dftest = adfuller(df[col].values)
        p_value = dftest[1]
        t_test = dftest[0] < dftest[4]["1%"]
        if p_value > 0.05 or not t_test:
            non_stationaries.append(col)
    except Exception:
        # skip non-numeric or problematic columns, if any
        pass

# %%
print(f"Non-Stationary Features Found: {len(non_stationaries)}")
print(non_stationaries)
# Out:
# Non-Stationary Features Found: 33
# ['Close', 'High', 'Low', 'Open', 'Volume', 'volume_adi', 'volume_obv', 'volume_vpt', 'volume_vwap', 'volatility_bbm', 'volatility_bbh', 'volatility_bbl', 'volatility_kcc', 'volatility_kch', 'volatility_kcl', 'volatility_dcl', 'volatility_dch', 'volatility_dcm', 'volatility_atr', 'trend_sma_fast', 'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow', 'trend_ichimoku_conv', 'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b', 'trend_visual_ichimoku_a', 'trend_visual_ichimoku_b', 'trend_psar_up', 'trend_psar_down', 'momentum_kama', 'others_cr']

# %%
# Convert non-stationaries to stationary
df_stationary = df.copy()
df_stationary[non_stationaries] = df_stationary[non_stationaries].pct_change()
df_stationary = df_stationary.iloc[1:]

# %%
# Find NaN Rows
na_list = df_stationary.columns[df_stationary.isna().any().tolist()]
df_stationary.drop(columns=na_list, inplace=True)

# Handle inf values
df_stationary.replace([np.inf, -np.inf], 0, inplace=True)
df_stationary.shape
# Out:
# (2859, 91)

# %% [markdown]
# ### Scaling and Splitting

# %%
# Split Target from Feature set
X = df_stationary.iloc[:, :-1]
y = df_stationary.iloc[:, -1]

# %%
# ==== Feature Scaling (AVOID LEAKAGE) ====
train_limit = int(0.8 * len(df_stationary))  # time-aware split
scaler = StandardScaler().fit(X.iloc[:train_limit].values)  # fit on TRAIN only
X_fs_train = scaler.transform(X.iloc[:train_limit].values)
X_fs_test  = scaler.transform(X.iloc[train_limit:].values)

# %%
X_train = X_fs_train
X_test  = X_fs_test
y_train = y[:train_limit]
y_test  = y[train_limit:]

# %% [markdown]
# ### PCA

# %%
# PCA
n_components = 25
pca = PCA(n_components=n_components)
pca_result = pca.fit(X_train)
X_train_pca = pca_result.transform(X_train)
X_test_pca = pca_result.transform(X_test)

# %%
# Calculate the variance explained by Principle Components
print("Variance of each component: ", pca.explained_variance_ratio_)
print("\n Total Variance Explained: ", round(sum(list(pca.explained_variance_ratio_)) * 100, 2))
# Out:
# Variance of each component:  [0.3759812  0.09723965 0.06246398 0.04351363 0.03857109 0.03089442
#  0.02489548 0.02200465 0.02086184 0.01957414 0.01950722 0.01627176
#  0.01294544 0.01235277 0.01209201 0.01132854 0.01115773 0.01030927
#  0.00998773 0.00949234 0.00829784 0.0079682  0.00761991 0.0070807
#  0.00643977]
#
#  Total Variance Explained:  89.89

# %%
# Reshape for LSTM input
X_train_3d = np.reshape(X_train_pca, (X_train_pca.shape[0], 1, X_train_pca.shape[1]))
X_test_3d = np.reshape(X_test_pca, (X_test_pca.shape[0], 1, X_test_pca.shape[1]))

# %% [markdown]
# ### LSTM

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(64, input_shape=(X_train_3d.shape[1], X_train_3d.shape[2]), return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
model.compile(optimizer=Adam(1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit model
history = model.fit(
    X_train_3d, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    verbose=1,
    shuffle=False
)
# Out:
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5041 - loss: 0.6994 - val_accuracy: 0.5262 - val_loss: 0.6912
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4978 - loss: 0.6972 - val_accuracy: 0.5218 - val_loss: 0.6906
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5128 - loss: 0.6925 - val_accuracy: 0.5262 - val_loss: 0.6902
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5130 - loss: 0.6919 - val_accuracy: 0.5218 - val_loss: 0.6898
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5063 - loss: 0.6900 - val_accuracy: 0.5328 - val_loss: 0.6895
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5234 - loss: 0.6924 - val_accuracy: 0.5393 - val_loss: 0.6893
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5386 - loss: 0.6901 - val_accuracy: 0.5284 - val_loss: 0.6892
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5242 - loss: 0.6877 - val_accuracy: 0.5284 - val_loss: 0.6892
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5380 - loss: 0.6881 - val_accuracy: 0.5306 - val_loss: 0.6891
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5591 - loss: 0.6858 - val_accuracy: 0.5328 - val_loss: 0.6891
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5394 - loss: 0.6860 - val_accuracy: 0.5371 - val_loss: 0.6891
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5330 - loss: 0.6874 - val_accuracy: 0.5459 - val_loss: 0.6891
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5611 - loss: 0.6835 - val_accuracy: 0.5415 - val_loss: 0.6891
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5661 - loss: 0.6848 - val_accuracy: 0.5371 - val_loss: 0.6890
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5675 - loss: 0.6866 - val_accuracy: 0.5393 - val_loss: 0.6891
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5791 - loss: 0.6798 - val_accuracy: 0.5437 - val_loss: 0.6890
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5488 - loss: 0.6828 - val_accuracy: 0.5415 - val_loss: 0.6891
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5247 - loss: 0.6893 - val_accuracy: 0.5459 - val_loss: 0.6890
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5624 - loss: 0.6788 - val_accuracy: 0.5546 - val_loss: 0.6891
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5734 - loss: 0.6781 - val_accuracy: 0.5480 - val_loss: 0.6891
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5717 - loss: 0.6787 - val_accuracy: 0.5415 - val_loss: 0.6891
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5693 - loss: 0.6810 - val_accuracy: 0.5415 - val_loss: 0.6892
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5630 - loss: 0.6785 - val_accuracy: 0.5459 - val_loss: 0.6892
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5852 - loss: 0.6750 - val_accuracy: 0.5437 - val_loss: 0.6893
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5625 - loss: 0.6764 - val_accuracy: 0.5437 - val_loss: 0.6893
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5475 - loss: 0.6770 - val_accuracy: 0.5415 - val_loss: 0.6893
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5802 - loss: 0.6771 - val_accuracy: 0.5393 - val_loss: 0.6893
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5781 - loss: 0.6769 - val_accuracy: 0.5415 - val_loss: 0.6894
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5771 - loss: 0.6755 - val_accuracy: 0.5415 - val_loss: 0.6894
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5775 - loss: 0.6732 - val_accuracy: 0.5306 - val_loss: 0.6896
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5742 - loss: 0.6743 - val_accuracy: 0.5262 - val_loss: 0.6897
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5861 - loss: 0.6711 - val_accuracy: 0.5306 - val_loss: 0.6898
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5829 - loss: 0.6717 - val_accuracy: 0.5393 - val_loss: 0.6899
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5724 - loss: 0.6750 - val_accuracy: 0.5393 - val_loss: 0.6899
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5841 - loss: 0.6740 - val_accuracy: 0.5415 - val_loss: 0.6900
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5892 - loss: 0.6685 - val_accuracy: 0.5415 - val_loss: 0.6902
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5631 - loss: 0.6706 - val_accuracy: 0.5459 - val_loss: 0.6903
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5875 - loss: 0.6678 - val_accuracy: 0.5459 - val_loss: 0.6903
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5960 - loss: 0.6691 - val_accuracy: 0.5524 - val_loss: 0.6905
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5943 - loss: 0.6668 - val_accuracy: 0.5459 - val_loss: 0.6907
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5727 - loss: 0.6693 - val_accuracy: 0.5459 - val_loss: 0.6907
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5876 - loss: 0.6688 - val_accuracy: 0.5480 - val_loss: 0.6908
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5990 - loss: 0.6632 - val_accuracy: 0.5502 - val_loss: 0.6909
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5941 - loss: 0.6661 - val_accuracy: 0.5437 - val_loss: 0.6909
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5963 - loss: 0.6680 - val_accuracy: 0.5480 - val_loss: 0.6910
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6037 - loss: 0.6614 - val_accuracy: 0.5546 - val_loss: 0.6912
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5750 - loss: 0.6656 - val_accuracy: 0.5502 - val_loss: 0.6914
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5882 - loss: 0.6649 - val_accuracy: 0.5459 - val_loss: 0.6916
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6070 - loss: 0.6650 - val_accuracy: 0.5502 - val_loss: 0.6917
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5864 - loss: 0.6641 - val_accuracy: 0.5524 - val_loss: 0.6917

# %%
# Predictions
y_pred_prob = model.predict(X_test_3d)
y_pred = (y_pred_prob > 0.5).astype(int)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, zero_division=0)
recall = recall_score(y_test, y_pred, zero_division=0)
f1 = f1_score(y_test, y_pred, zero_division=0)

print(f"Test Accuracy (LSTM): {accuracy:.3f}")
print(f"Test Precision (LSTM): {precision:.3f}")
print(f"Test Recall (LSTM): {recall:.3f}")
print(f"Test F1 Score (LSTM): {f1:.3f}")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Test Accuracy (LSTM): 0.545
# Test Precision (LSTM): 0.560
# Test Recall (LSTM): 0.471
# Test F1 Score (LSTM): 0.511

# %% [markdown]
# ### Trading Strategy

# %%
# Align df_preprocess with df_stationary indexing (after first diff)
df_preprocess = df.iloc[1:]  # same length as df_stationary
df_test = df_preprocess.iloc[train_limit:].copy()

# %%
# If the classification is 1 then buy, else if 0 then do nothing - long only strategy
df_test["LSTM_Signal"] = y_pred
# Use prediction at t for the horizon Close_t -> Close_{t+1}
df_test["Main_Signal"] = df_test["LSTM_Signal"]

# %%
# Benchmark Returns (Close-to-Close)
df_test["lrets_bench"] = np.log(df_test["Close"].shift(-1) / df_test["Close"])
df_test["bench_prod"] = df_test["lrets_bench"].cumsum()
df_test["bench_prod_exp"] = np.exp(df_test["bench_prod"]) - 1

# %%
# Strategy Returns (same Close-to-Close horizon)
df_test["lrets"] = np.log(df_test["Close"].shift(-1) / df_test["Close"])
df_test["lrets_strat"] = df_test["lrets"] * df_test["Main_Signal"]
df_test["lrets_prod"] = df_test["lrets_strat"].cumsum()
df_test["strat_prod_exp"] = np.exp(df_test["lrets_prod"]) - 1

# %%
# Drop NA values
df_test.dropna(inplace=True)

# %% [markdown]
# ### Metrics

# %%
# Sharpe Ratio
def sharpe_ratio(returns_series):
    N = 365
    NSQRT = np.sqrt(N)
    rf = 0  # Assuming risk-free rate = 0
    mean = returns_series.mean() * N
    sigma = returns_series.std() * NSQRT
    return round((mean - rf) / sigma, 2)

# Max Drawdown
def max_drawdown(returns):
    equity = np.exp(np.cumsum(returns))
    running_max = np.maximum.accumulate(equity)
    drawdown = (equity / running_max) - 1.0
    return drawdown.min()


def win_ratio(returns, signals):
    returns = pd.Series(returns)
    signals = pd.Series(signals).reindex(returns.index).fillna(0)

    # Filter only trade days
    trade_returns = returns[signals == 1]

    if len(trade_returns) == 0:
        return np.nan  # no trades executed

    wins = (trade_returns > 0).sum()
    return round(wins / len(trade_returns), 3)

# %%
# Calculate Metrics
bench_rets = round(df_test["bench_prod_exp"].values[-1] * 100, 1)
strat_rets = round(df_test["strat_prod_exp"].values[-1] * 100, 1)
bench_sharpe = sharpe_ratio(df_test["lrets_bench"].values)
strat_sharpe = sharpe_ratio(df_test["lrets_strat"].values)

# Max Drawdown and Win Ratio
bench_drawdown = max_drawdown(df_test["lrets_bench"].values)
strat_drawdown = max_drawdown(df_test["lrets_strat"].values)
bench_win_ratio = win_ratio(df_test["lrets_bench"], np.ones_like(df_test["lrets_bench"]))
strat_win_ratio = win_ratio(df_test["lrets_strat"], df_test["Main_Signal"])

print(f"Returns Benchmark: {bench_rets}%")
print(f"Returns Strategy: {strat_rets}%")
print("---- ---- ---- ---- ---- ----")
print(f"Sharpe Benchmark: {bench_sharpe}")
print(f"Sharpe Strategy: {strat_sharpe}")
print("---- ---- ---- ---- ---- ----")
print(f"Max Drawdown Benchmark: {bench_drawdown}")
print(f"Max Drawdown Strategy: {strat_drawdown}")
print("---- ---- ---- ---- ---- ----")
print(f"Win Ratio Benchmark: {bench_win_ratio}")
print(f"Win Ratio Strategy: {strat_win_ratio}")
# Out:
# Returns Benchmark: 70.9%
# Returns Strategy: 129.3%
# ---- ---- ---- ---- ---- ----
# Sharpe Benchmark: 0.72
# Sharpe Strategy: 1.48
# ---- ---- ---- ---- ---- ----
# Max Drawdown Benchmark: -0.28144478116207905
# Max Drawdown Strategy: -0.1857891944806297
# ---- ---- ---- ---- ---- ----
# Win Ratio Benchmark: nan
# Win Ratio Strategy: 0.562

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(18, 10))
plt.plot(df_test["bench_prod_exp"], label="Benchmark")
plt.plot(df_test["strat_prod_exp"], label="LSTM Strategy")
plt.legend()
plt.title("Equity Curves")
plt.xlabel("Date")
plt.ylabel("Returns")
plt.grid(True)
plt.show()
